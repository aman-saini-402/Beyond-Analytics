# %%
from bayes_opt import BayesianOptimization
from sklearn.model_selection import KFold
import pandas as pd, numpy as np
import pickle
import lightgbm as lgb
from catboost import Pool, CatBoostRegressor
from sklearn.metrics import mean_squared_error as mse
import warnings
warnings.filterwarnings('ignore')
seed = 21
np.random.seed(seed)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
with open("../input/ba-training-data-3/training_data.pkl", "rb") as f:
    train_ = pickle.load(f)

# %%
X = train_.drop(['UNIQUE_IDENTIFIER', 'Y1', 'Y2'], axis=1)
y = train_[["Y1", "Y2"]]

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
le2 = LabelEncoder()
X['CATEGORY_1'] = le1.fit_transform(X['CATEGORY_1'])
X['CATEGORY_2'] = le2.fit_transform(X['CATEGORY_2'])

# %% [markdown]
# # LightGBM

# %%
# Prediction arrays
val_pred1 = np.zeros(X.shape[0])
val_pred2 = np.zeros(X.shape[0])

FOLDS = 5

def lgbm_cv1(learning_rate, num_leaves, feature_fraction, feature_fraction_bynode, bagging_fraction, bagging_freq, min_data_in_leaf, min_sum_hessian_in_leaf, lambda_l1, lambda_l2):
    params = {  'seed': seed,
                'feature_fraction_seed': seed,
                'bagging_seed': seed,
                'drop_seed': seed,
                'data_random_seed': seed,
                'objective': 'rmse',
                'boosting': 'gbdt',
                'verbosity': -1,
                'n_jobs': -1}
    params['learning_rate'] = max(min(learning_rate, 1), 0)
    params["num_leaves"] = int(round(num_leaves))
    params['feature_fraction'] = max(min(feature_fraction, 1), 0)
    params['feature_fraction_bynode'] = max(min(feature_fraction_bynode, 1), 0)
    params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
    params['min_data_in_leaf'] = int(round(min_data_in_leaf))
    params['min_sum_hessian_in_leaf'] = min_sum_hessian_in_leaf
    params['lambda_l1'] = lambda_l1
    params['lambda_l2'] = lambda_l2
    
    # K-fold cross valiation
    kfold = KFold(n_splits=FOLDS)
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X, y)):
        print("#"*40)
        print("Training Fold - ", fold+1)
        X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
        X_val, y_val     = X.iloc[val_idx]  , y.iloc[val_idx]

        # create lgb datasets
        train_data1 = lgb.Dataset(X_train, y_train.iloc[:,0], categorical_feature = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])
        val_data1   = lgb.Dataset(X_val,   y_val.iloc[:,0],   categorical_feature = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])

        # Train model
        print("#"*20)
        print("Training for Y1")
        model1 = lgb.train(params = params,
                         train_set = train_data1,
                         valid_sets = [train_data1, val_data1],
                         num_boost_round = 100000,
                         valid_names=["training", "validation"],
                         early_stopping_rounds = 1000,
                         verbose_eval = 500)

        # Predict validation set
        val_pred1[val_idx] = model1.predict(X_val)
    
    return -np.sqrt(mse(train_["Y1"], val_pred1))

# %%
pbounds1 = {'learning_rate': (0.1, 0.4),
        'num_leaves': (300, 800),
        'feature_fraction': (0.6, 0.99),
        'feature_fraction_bynode': (0.1, 0.6),
        'bagging_fraction': (0.4, 1),
        'bagging_freq': (60, 100),
        'min_data_in_leaf': (100, 500),
        'min_sum_hessian_in_leaf':(30, 80),
       'lambda_l1': (3, 10),
        'lambda_l2': (0.01, 2)}

# %%
lgbm_bo1 = BayesianOptimization(f = lgbm_cv1, pbounds = pbounds1, verbose = 2, random_state = seed)

lgbm_bo1.maximize(init_points = 5, n_iter = 20)
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | featur... | lambda_l1 | lambda_l2 | learni... | min_da... | min_su... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.21752	validation's rmse: 6.11987
# [1000]	training's rmse: 4.25562	validation's rmse: 6.31366
# Early stopping, best iteration is:
# [16]	training's rmse: 6.99874	validation's rmse: 5.63904
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.29466	validation's rmse: 5.62451
# [1000]	training's rmse: 4.32358	validation's rmse: 5.82598
# Early stopping, best iteration is:
# [57]	training's rmse: 6.73215	validation's rmse: 5.4197
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.66745	validation's rmse: 8.61947
# [1000]	training's rmse: 3.82359	validation's rmse: 8.71665
# Early stopping, best iteration is:
# [218]	training's rmse: 5.33581	validation's rmse: 8.56682
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.98584	validation's rmse: 6.9699
# [1000]	training's rmse: 4.05252	validation's rmse: 7.10607
# Early stopping, best iteration is:
# [87]	training's rmse: 6.26401	validation's rmse: 6.81808
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.11415	validation's rmse: 6.98053
# [1000]	training's rmse: 4.2203	validation's rmse: 7.04359
# Early stopping, best iteration is:
# [169]	training's rmse: 5.98384	validation's rmse: 6.90967
# |  1        | -6.764    |  0.4292   |  71.56    |  0.8812   |  0.1108   |  4.441    |  0.111    |  0.1907   |  365.6    |  45.41    |  591.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.0601	validation's rmse: 6.22644
# [1000]	training's rmse: 4.03221	validation's rmse: 6.43785
# Early stopping, best iteration is:
# [11]	training's rmse: 7.04185	validation's rmse: 5.68437
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.15463	validation's rmse: 5.67688
# [1000]	training's rmse: 4.15454	validation's rmse: 5.8978
# Early stopping, best iteration is:
# [151]	training's rmse: 6.27885	validation's rmse: 5.48117
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.52095	validation's rmse: 8.69072
# [1000]	training's rmse: 3.64234	validation's rmse: 8.75868
# Early stopping, best iteration is:
# [137]	training's rmse: 5.54492	validation's rmse: 8.62995
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.8538	validation's rmse: 7.14226
# [1000]	training's rmse: 3.87416	validation's rmse: 7.29113
# Early stopping, best iteration is:
# [76]	training's rmse: 6.28065	validation's rmse: 6.84597
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.00549	validation's rmse: 7.08895
# [1000]	training's rmse: 4.05654	validation's rmse: 7.21713
# Early stopping, best iteration is:
# [105]	training's rmse: 6.20217	validation's rmse: 6.93713
# |  2        | -6.809    |  0.4417   |  94.7     |  0.652    |  0.1891   |  6.472    |  1.729    |  0.3277   |  488.2    |  67.97    |  492.1    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.05845	validation's rmse: 6.60402
# [1000]	training's rmse: 1.8802	validation's rmse: 6.82724
# Early stopping, best iteration is:
# [6]	training's rmse: 6.85855	validation's rmse: 5.65807
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.04206	validation's rmse: 5.93449
# [1000]	training's rmse: 1.90404	validation's rmse: 6.12905
# Early stopping, best iteration is:
# [7]	training's rmse: 6.85569	validation's rmse: 5.33615
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.47326	validation's rmse: 8.81644
# [1000]	training's rmse: 1.38547	validation's rmse: 8.87502
# Early stopping, best iteration is:
# [16]	training's rmse: 5.78411	validation's rmse: 8.55885
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.0197	validation's rmse: 7.26599
# [1000]	training's rmse: 1.92275	validation's rmse: 7.39814
# Early stopping, best iteration is:
# [21]	training's rmse: 6.30227	validation's rmse: 6.77466
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.15134	validation's rmse: 7.21669
# [1000]	training's rmse: 2.01248	validation's rmse: 7.43515
# Early stopping, best iteration is:
# [19]	training's rmse: 6.30202	validation's rmse: 6.79859
# |  3        | -6.721    |  0.6452   |  88.53    |  0.7056   |  0.5271   |  9.392    |  1.524    |  0.255    |  167.1    |  44.93    |  442.0    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.95566	validation's rmse: 6.60516
# [1000]	training's rmse: 1.73884	validation's rmse: 6.83307
# Early stopping, best iteration is:
# [6]	training's rmse: 6.89633	validation's rmse: 5.65278
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.04399	validation's rmse: 6.10143
# [1000]	training's rmse: 1.82386	validation's rmse: 6.28752
# Early stopping, best iteration is:
# [6]	training's rmse: 6.93628	validation's rmse: 5.4268
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.5504	validation's rmse: 8.89021
# [1000]	training's rmse: 1.47172	validation's rmse: 8.98885
# Early stopping, best iteration is:
# [19]	training's rmse: 5.83542	validation's rmse: 8.68469
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.87019	validation's rmse: 7.41157
# [1000]	training's rmse: 1.68553	validation's rmse: 7.53058
# Early stopping, best iteration is:
# [10]	training's rmse: 6.5161	validation's rmse: 6.7829
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.98765	validation's rmse: 7.30625
# [1000]	training's rmse: 1.79398	validation's rmse: 7.47637
# Early stopping, best iteration is:
# [33]	training's rmse: 6.09242	validation's rmse: 6.908
# |  4        | -6.791    |  0.5963   |  78.41    |  0.8123   |  0.2087   |  8.599    |  1.456    |  0.3548   |  207.0    |  60.74    |  626.4    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.60513	validation's rmse: 6.27679
# [1000]	training's rmse: 3.51783	validation's rmse: 6.54848
# Early stopping, best iteration is:
# [12]	training's rmse: 6.9392	validation's rmse: 5.62708
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.70151	validation's rmse: 5.85735
# [1000]	training's rmse: 3.55864	validation's rmse: 6.09602
# Early stopping, best iteration is:
# [18]	training's rmse: 6.89739	validation's rmse: 5.4551
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.16672	validation's rmse: 8.64873
# [1000]	training's rmse: 3.1967	validation's rmse: 8.7198
# Early stopping, best iteration is:
# [118]	training's rmse: 5.4538	validation's rmse: 8.60146
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.4848	validation's rmse: 7.20396
# [1000]	training's rmse: 3.39589	validation's rmse: 7.37495
# Early stopping, best iteration is:
# [75]	training's rmse: 6.13545	validation's rmse: 6.91376
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.59385	validation's rmse: 7.16471
# [1000]	training's rmse: 3.54663	validation's rmse: 7.30251
# Early stopping, best iteration is:
# [108]	training's rmse: 6.0013	validation's rmse: 6.97595
# |  5        | -6.81     |  0.6321   |  76.41    |  0.916    |  0.4002   |  9.288    |  0.9852   |  0.3485   |  443.6    |  69.42    |  743.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.28571	validation's rmse: 6.42041
# [1000]	training's rmse: 3.08686	validation's rmse: 6.63117
# Early stopping, best iteration is:
# [7]	training's rmse: 7.04598	validation's rmse: 5.71269
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.39528	validation's rmse: 5.88515
# [1000]	training's rmse: 3.20461	validation's rmse: 6.12765
# Early stopping, best iteration is:
# [24]	training's rmse: 6.83997	validation's rmse: 5.47019
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.83811	validation's rmse: 8.71484
# [1000]	training's rmse: 2.81092	validation's rmse: 8.82724
# Early stopping, best iteration is:
# [48]	training's rmse: 5.78728	validation's rmse: 8.58431
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.10476	validation's rmse: 7.24456
# [1000]	training's rmse: 2.92802	validation's rmse: 7.38193
# Early stopping, best iteration is:
# [35]	training's rmse: 6.39854	validation's rmse: 6.85613
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.25272	validation's rmse: 7.15433
# [1000]	training's rmse: 3.10552	validation's rmse: 7.3005
# Early stopping, best iteration is:
# [45]	training's rmse: 6.3314	validation's rmse: 6.89903
# |  6        | -6.795    |  0.4388   |  76.91    |  0.7303   |  0.1333   |  8.361    |  0.862    |  0.3772   |  362.3    |  37.28    |  593.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.45233	validation's rmse: 6.19435
# [1000]	training's rmse: 3.30011	validation's rmse: 6.44429
# Early stopping, best iteration is:
# [11]	training's rmse: 6.91506	validation's rmse: 5.61059
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.47923	validation's rmse: 5.77468
# [1000]	training's rmse: 3.31664	validation's rmse: 6.04518
# Early stopping, best iteration is:
# [54]	training's rmse: 6.52244	validation's rmse: 5.39483
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.8708	validation's rmse: 8.76609
# [1000]	training's rmse: 2.82254	validation's rmse: 8.83302
# Early stopping, best iteration is:
# [62]	training's rmse: 5.63253	validation's rmse: 8.60302
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.27062	validation's rmse: 7.02371
# [1000]	training's rmse: 3.11723	validation's rmse: 7.18002
# Early stopping, best iteration is:
# [23]	training's rmse: 6.45432	validation's rmse: 6.72962
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.35805	validation's rmse: 7.14348
# [1000]	training's rmse: 3.27743	validation's rmse: 7.30085
# Early stopping, best iteration is:
# [30]	training's rmse: 6.40031	validation's rmse: 6.86671
# |  7        | -6.738    |  0.8989   |  80.71    |  0.8292   |  0.4099   |  3.059    |  1.297    |  0.185    |  250.0    |  65.89    |  703.6    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.9387	validation's rmse: 6.23385
# [1000]	training's rmse: 3.90454	validation's rmse: 6.47904
# Early stopping, best iteration is:
# [8]	training's rmse: 7.05957	validation's rmse: 5.6285
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.03236	validation's rmse: 5.68878
# [1000]	training's rmse: 3.99296	validation's rmse: 5.91527
# Early stopping, best iteration is:
# [50]	training's rmse: 6.71402	validation's rmse: 5.41333
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.42386	validation's rmse: 8.67871
# [1000]	training's rmse: 3.54815	validation's rmse: 8.72725
# Early stopping, best iteration is:
# [87]	training's rmse: 5.70371	validation's rmse: 8.60541
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.76996	validation's rmse: 7.10311
# [1000]	training's rmse: 3.75989	validation's rmse: 7.29883
# Early stopping, best iteration is:
# [32]	training's rmse: 6.52353	validation's rmse: 6.85589
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.88447	validation's rmse: 7.0791
# [1000]	training's rmse: 3.91595	validation's rmse: 7.19655
# Early stopping, best iteration is:
# [50]	training's rmse: 6.42679	validation's rmse: 6.92536
# |  8        | -6.782    |  0.992    |  90.93    |  0.7178   |  0.3384   |  5.154    |  0.8136   |  0.3034   |  464.4    |  70.21    |  595.0    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.24415	validation's rmse: 6.33733
# [1000]	training's rmse: 3.05625	validation's rmse: 6.5207
# Early stopping, best iteration is:
# [12]	training's rmse: 6.98262	validation's rmse: 5.66694
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.38715	validation's rmse: 5.83076
# [1000]	training's rmse: 3.1742	validation's rmse: 6.07382
# Early stopping, best iteration is:
# [22]	training's rmse: 6.86038	validation's rmse: 5.44667
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.8121	validation's rmse: 8.72247
# [1000]	training's rmse: 2.76212	validation's rmse: 8.81424
# Early stopping, best iteration is:
# [99]	training's rmse: 5.40603	validation's rmse: 8.60008
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.1175	validation's rmse: 7.23367
# [1000]	training's rmse: 2.96217	validation's rmse: 7.42408
# Early stopping, best iteration is:
# [33]	training's rmse: 6.46078	validation's rmse: 6.91884
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.27723	validation's rmse: 7.12936
# [1000]	training's rmse: 3.12443	validation's rmse: 7.30862
# Early stopping, best iteration is:
# [48]	training's rmse: 6.302	validation's rmse: 6.94346
# |  9        | -6.809    |  0.4981   |  72.06    |  0.7151   |  0.1109   |  8.544    |  1.192    |  0.3387   |  327.3    |  77.45    |  314.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.22258	validation's rmse: 6.06056
# [1000]	training's rmse: 4.22945	validation's rmse: 6.33018
# Early stopping, best iteration is:
# [15]	training's rmse: 7.0065	validation's rmse: 5.58782
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.27273	validation's rmse: 5.61554
# [1000]	training's rmse: 4.31027	validation's rmse: 5.84618
# Early stopping, best iteration is:
# [81]	training's rmse: 6.60087	validation's rmse: 5.37877
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.61728	validation's rmse: 8.67461
# [1000]	training's rmse: 3.7669	validation's rmse: 8.72899
# Early stopping, best iteration is:
# [154]	training's rmse: 5.52908	validation's rmse: 8.61803
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.00764	validation's rmse: 6.99014
# [1000]	training's rmse: 4.0722	validation's rmse: 7.15117
# Early stopping, best iteration is:
# [98]	training's rmse: 6.22089	validation's rmse: 6.842
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 5.09513	validation's rmse: 7.04755
# [1000]	training's rmse: 4.25752	validation's rmse: 7.16834
# Early stopping, best iteration is:
# [59]	training's rmse: 6.41021	validation's rmse: 6.93781
# |  10       | -6.773    |  0.782    |  66.4     |  0.6099   |  0.5737   |  3.572    |  1.569    |  0.1417   |  315.6    |  72.92    |  424.5    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.12654	validation's rmse: 6.36766
# [1000]	training's rmse: 2.88245	validation's rmse: 6.56401
# Early stopping, best iteration is:
# [11]	training's rmse: 6.87611	validation's rmse: 5.64729
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.23311	validation's rmse: 5.73301
# [1000]	training's rmse: 3.00218	validation's rmse: 5.94362
# Early stopping, best iteration is:
# [14]	training's rmse: 6.85291	validation's rmse: 5.32648
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.60654	validation's rmse: 8.77853
# [1000]	training's rmse: 2.51695	validation's rmse: 8.86479
# Early stopping, best iteration is:
# [52]	training's rmse: 5.64871	validation's rmse: 8.5992
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.984	validation's rmse: 7.10568
# [1000]	training's rmse: 2.78803	validation's rmse: 7.27173
# Early stopping, best iteration is:
# [33]	training's rmse: 6.35345	validation's rmse: 6.77874
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.07345	validation's rmse: 7.08742
# [1000]	training's rmse: 2.91032	validation's rmse: 7.25745
# Early stopping, best iteration is:
# [25]	training's rmse: 6.42368	validation's rmse: 6.83254
# |  11       | -6.736    |  0.7819   |  75.83    |  0.7946   |  0.1328   |  8.3      |  0.8521   |  0.2078   |  220.5    |  79.68    |  306.5    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.91225	validation's rmse: 6.17743
# [1000]	training's rmse: 3.85031	validation's rmse: 6.43541
# Early stopping, best iteration is:
# [21]	training's rmse: 6.94367	validation's rmse: 5.654
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.99885	validation's rmse: 5.64632
# [1000]	training's rmse: 3.9582	validation's rmse: 5.84303
# Early stopping, best iteration is:
# [64]	training's rmse: 6.64859	validation's rmse: 5.42149
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.37217	validation's rmse: 8.63592
# [1000]	training's rmse: 3.4351	validation's rmse: 8.684
# Early stopping, best iteration is:
# [345]	training's rmse: 4.77228	validation's rmse: 8.59219
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.72739	validation's rmse: 7.03887
# [1000]	training's rmse: 3.71597	validation's rmse: 7.20259
# Early stopping, best iteration is:
# [83]	training's rmse: 6.21472	validation's rmse: 6.81934
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.85798	validation's rmse: 7.02731
# [1000]	training's rmse: 3.86166	validation's rmse: 7.16016
# Early stopping, best iteration is:
# [64]	training's rmse: 6.35927	validation's rmse: 6.91479
# |  12       | -6.775    |  0.6879   |  92.58    |  0.6205   |  0.1104   |  3.739    |  1.521    |  0.2267   |  333.3    |  71.81    |  404.3    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.18378	validation's rmse: 6.20747
# [1000]	training's rmse: 2.94756	validation's rmse: 6.41281
# Early stopping, best iteration is:
# [15]	training's rmse: 6.87385	validation's rmse: 5.66234
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.26045	validation's rmse: 5.65214
# [1000]	training's rmse: 3.05004	validation's rmse: 5.80612
# Early stopping, best iteration is:
# [20]	training's rmse: 6.8197	validation's rmse: 5.34386
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.66549	validation's rmse: 8.75684
# [1000]	training's rmse: 2.52506	validation's rmse: 8.79597
# Early stopping, best iteration is:
# [45]	training's rmse: 5.73107	validation's rmse: 8.57679
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.08388	validation's rmse: 7.09825
# [1000]	training's rmse: 2.90888	validation's rmse: 7.24726
# Early stopping, best iteration is:
# [48]	training's rmse: 6.24499	validation's rmse: 6.75539
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.17364	validation's rmse: 7.04488
# [1000]	training's rmse: 3.02308	validation's rmse: 7.14504
# Early stopping, best iteration is:
# [75]	training's rmse: 6.04817	validation's rmse: 6.90432
# |  13       | -6.745    |  0.5887   |  65.8     |  0.6874   |  0.1125   |  3.447    |  0.8363   |  0.1436   |  167.7    |  40.95    |  310.9    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.3177	validation's rmse: 6.3397
# [1000]	training's rmse: 3.13629	validation's rmse: 6.59042
# Early stopping, best iteration is:
# [10]	training's rmse: 6.89276	validation's rmse: 5.61703
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.37148	validation's rmse: 5.89136
# [1000]	training's rmse: 3.16852	validation's rmse: 6.15043
# Early stopping, best iteration is:
# [11]	training's rmse: 6.9796	validation's rmse: 5.43207
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.83277	validation's rmse: 8.73751
# [1000]	training's rmse: 2.7968	validation's rmse: 8.81631
# Early stopping, best iteration is:
# [66]	training's rmse: 5.61946	validation's rmse: 8.62966
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.15447	validation's rmse: 7.19366
# [1000]	training's rmse: 2.99167	validation's rmse: 7.37566
# Early stopping, best iteration is:
# [38]	training's rmse: 6.36426	validation's rmse: 6.8272
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.29203	validation's rmse: 7.21579
# [1000]	training's rmse: 3.15674	validation's rmse: 7.41584
# Early stopping, best iteration is:
# [22]	training's rmse: 6.50252	validation's rmse: 6.92209
# |  14       | -6.783    |  0.6042   |  68.55    |  0.9815   |  0.399    |  4.104    |  1.654    |  0.2541   |  305.6    |  47.09    |  387.7    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.41105	validation's rmse: 6.81573
# [1000]	training's rmse: 1.33137	validation's rmse: 6.95989
# Early stopping, best iteration is:
# [6]	training's rmse: 6.75752	validation's rmse: 5.70863
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.43572	validation's rmse: 6.14775
# [1000]	training's rmse: 1.33445	validation's rmse: 6.30649
# Early stopping, best iteration is:
# [6]	training's rmse: 6.84483	validation's rmse: 5.34534
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 1.89056	validation's rmse: 8.91578
# [1000]	training's rmse: 0.89643	validation's rmse: 8.98333
# Early stopping, best iteration is:
# [13]	training's rmse: 5.7879	validation's rmse: 8.62649
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.41273	validation's rmse: 7.432
# [1000]	training's rmse: 1.37613	validation's rmse: 7.54746
# Early stopping, best iteration is:
# [8]	training's rmse: 6.48284	validation's rmse: 6.73871
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.55235	validation's rmse: 7.45103
# [1000]	training's rmse: 1.48816	validation's rmse: 7.72712
# Early stopping, best iteration is:
# [10]	training's rmse: 6.36751	validation's rmse: 6.83866
# |  15       | -6.749    |  0.5741   |  85.35    |  0.7759   |  0.5798   |  4.605    |  0.9399   |  0.3197   |  153.0    |  47.86    |  328.9    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.55082	validation's rmse: 6.4072
# [1000]	training's rmse: 2.37256	validation's rmse: 6.63119
# Early stopping, best iteration is:
# [11]	training's rmse: 6.76548	validation's rmse: 5.61428
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.5836	validation's rmse: 5.8798
# [1000]	training's rmse: 2.39837	validation's rmse: 6.09433
# Early stopping, best iteration is:
# [14]	training's rmse: 6.7741	validation's rmse: 5.30672
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.94674	validation's rmse: 8.7569
# [1000]	training's rmse: 1.81527	validation's rmse: 8.8334
# Early stopping, best iteration is:
# [28]	training's rmse: 5.73812	validation's rmse: 8.59262
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.48167	validation's rmse: 7.13965
# [1000]	training's rmse: 2.36684	validation's rmse: 7.28544
# Early stopping, best iteration is:
# [25]	training's rmse: 6.29691	validation's rmse: 6.69193
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.6161	validation's rmse: 7.18969
# [1000]	training's rmse: 2.49212	validation's rmse: 7.39045
# Early stopping, best iteration is:
# [34]	training's rmse: 6.17874	validation's rmse: 6.87107
# |  16       | -6.716    |  0.7446   |  94.57    |  0.9012   |  0.2724   |  6.697    |  0.05709  |  0.1759   |  154.2    |  58.38    |  622.1    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.79227	validation's rmse: 6.29592
# [1000]	training's rmse: 3.69613	validation's rmse: 6.5408
# Early stopping, best iteration is:
# [9]	training's rmse: 7.01688	validation's rmse: 5.57796
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.85986	validation's rmse: 5.76689
# [1000]	training's rmse: 3.80186	validation's rmse: 5.99608
# Early stopping, best iteration is:
# [40]	training's rmse: 6.75717	validation's rmse: 5.45054
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.29342	validation's rmse: 8.69072
# [1000]	training's rmse: 3.3865	validation's rmse: 8.75514
# Early stopping, best iteration is:
# [111]	training's rmse: 5.53593	validation's rmse: 8.62957
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.63016	validation's rmse: 7.1131
# [1000]	training's rmse: 3.59553	validation's rmse: 7.28069
# Early stopping, best iteration is:
# [43]	training's rmse: 6.39788	validation's rmse: 6.86452
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.76684	validation's rmse: 7.15979
# [1000]	training's rmse: 3.7621	validation's rmse: 7.30065
# Early stopping, best iteration is:
# [39]	training's rmse: 6.4736	validation's rmse: 6.96461
# |  17       | -6.796    |  0.5449   |  69.79    |  0.9568   |  0.3036   |  6.66     |  1.165    |  0.3357   |  463.9    |  42.27    |  338.3    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.37331	validation's rmse: 6.41627
# [1000]	training's rmse: 2.11035	validation's rmse: 6.66241
# Early stopping, best iteration is:
# [6]	training's rmse: 6.96538	validation's rmse: 5.66173
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.40201	validation's rmse: 5.91699
# [1000]	training's rmse: 2.18369	validation's rmse: 6.16036
# Early stopping, best iteration is:
# [7]	training's rmse: 6.95581	validation's rmse: 5.36118
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.87541	validation's rmse: 8.92056
# [1000]	training's rmse: 1.7436	validation's rmse: 8.9528
# Early stopping, best iteration is:
# [28]	training's rmse: 5.76863	validation's rmse: 8.63017
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.22187	validation's rmse: 7.1539
# [1000]	training's rmse: 2.01845	validation's rmse: 7.29893
# Early stopping, best iteration is:
# [16]	training's rmse: 6.43933	validation's rmse: 6.77103
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.35175	validation's rmse: 7.1055
# [1000]	training's rmse: 2.14652	validation's rmse: 7.27158
# Early stopping, best iteration is:
# [123]	training's rmse: 5.30848	validation's rmse: 6.918
# |  18       | -6.767    |  0.6018   |  64.98    |  0.8046   |  0.2193   |  3.286    |  0.2089   |  0.272    |  200.2    |  45.77    |  653.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.82723	validation's rmse: 6.52515
# [1000]	training's rmse: 2.57258	validation's rmse: 6.79418
# Early stopping, best iteration is:
# [7]	training's rmse: 6.94288	validation's rmse: 5.70986
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.95536	validation's rmse: 6.08741
# [1000]	training's rmse: 2.67226	validation's rmse: 6.36658
# Early stopping, best iteration is:
# [17]	training's rmse: 6.84865	validation's rmse: 5.44139
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.45073	validation's rmse: 8.81261
# [1000]	training's rmse: 2.38653	validation's rmse: 8.90676
# Early stopping, best iteration is:
# [31]	training's rmse: 5.81033	validation's rmse: 8.65633
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.68863	validation's rmse: 7.31506
# [1000]	training's rmse: 2.47742	validation's rmse: 7.4712
# Early stopping, best iteration is:
# [17]	training's rmse: 6.53232	validation's rmse: 6.90838
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.85031	validation's rmse: 7.23041
# [1000]	training's rmse: 2.64863	validation's rmse: 7.45806
# Early stopping, best iteration is:
# [75]	training's rmse: 5.91132	validation's rmse: 6.8851
# |  19       | -6.816    |  0.6387   |  61.58    |  0.8991   |  0.4424   |  9.66     |  1.531    |  0.3591   |  319.9    |  63.14    |  660.9    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.03586	validation's rmse: 6.55791
# [1000]	training's rmse: 1.04861	validation's rmse: 6.69626
# Early stopping, best iteration is:
# [7]	training's rmse: 6.76424	validation's rmse: 5.69378
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.07449	validation's rmse: 6.03151
# [1000]	training's rmse: 1.04565	validation's rmse: 6.153
# Early stopping, best iteration is:
# [8]	training's rmse: 6.74183	validation's rmse: 5.33479
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 1.61601	validation's rmse: 8.77538
# [1000]	training's rmse: 0.732092	validation's rmse: 8.84718
# Early stopping, best iteration is:
# [33]	training's rmse: 5.26034	validation's rmse: 8.50031
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.08731	validation's rmse: 7.29412
# [1000]	training's rmse: 1.12441	validation's rmse: 7.3162
# Early stopping, best iteration is:
# [9]	training's rmse: 6.39603	validation's rmse: 6.77462
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.28706	validation's rmse: 7.41224
# [1000]	training's rmse: 1.2892	validation's rmse: 7.58274
# Early stopping, best iteration is:
# [11]	training's rmse: 6.30984	validation's rmse: 6.86148
# |  20       | -6.725    |  0.4371   |  72.74    |  0.7653   |  0.3068   |  8.863    |  1.257    |  0.2497   |  112.0    |  31.24    |  598.7    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.05043	validation's rmse: 6.35231
# [1000]	training's rmse: 2.85138	validation's rmse: 6.55457
# Early stopping, best iteration is:
# [9]	training's rmse: 6.87396	validation's rmse: 5.61778
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 4.08692	validation's rmse: 5.90245
# [1000]	training's rmse: 2.85001	validation's rmse: 6.18641
# Early stopping, best iteration is:
# [10]	training's rmse: 6.91232	validation's rmse: 5.40641
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.53783	validation's rmse: 8.81425
# [1000]	training's rmse: 2.44155	validation's rmse: 8.90385
# Early stopping, best iteration is:
# [59]	training's rmse: 5.57886	validation's rmse: 8.59409
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.85397	validation's rmse: 7.18765
# [1000]	training's rmse: 2.6959	validation's rmse: 7.35524
# Early stopping, best iteration is:
# [22]	training's rmse: 6.44121	validation's rmse: 6.77572
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.98192	validation's rmse: 7.15757
# [1000]	training's rmse: 2.84006	validation's rmse: 7.34329
# Early stopping, best iteration is:
# [25]	training's rmse: 6.38043	validation's rmse: 6.89885
# |  21       | -6.755    |  0.8481   |  85.94    |  0.6255   |  0.5777   |  9.819    |  1.247    |  0.2447   |  256.0    |  57.05    |  374.9    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.76687	validation's rmse: 6.51288
# [1000]	training's rmse: 2.48476	validation's rmse: 6.74276
# Early stopping, best iteration is:
# [9]	training's rmse: 6.92721	validation's rmse: 5.68224
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.83222	validation's rmse: 6.01429
# [1000]	training's rmse: 2.58711	validation's rmse: 6.27561
# Early stopping, best iteration is:
# [35]	training's rmse: 6.569	validation's rmse: 5.38149
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.34154	validation's rmse: 8.82196
# [1000]	training's rmse: 2.25163	validation's rmse: 8.90043
# Early stopping, best iteration is:
# [47]	training's rmse: 5.65767	validation's rmse: 8.61647
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.62143	validation's rmse: 7.27917
# [1000]	training's rmse: 2.41143	validation's rmse: 7.42381
# Early stopping, best iteration is:
# [29]	training's rmse: 6.32914	validation's rmse: 6.88726
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.78067	validation's rmse: 7.35179
# [1000]	training's rmse: 2.58936	validation's rmse: 7.58516
# Early stopping, best iteration is:
# [93]	training's rmse: 5.77805	validation's rmse: 6.97946
# |  22       | -6.806    |  0.8989   |  64.53    |  0.8067   |  0.4847   |  8.189    |  1.613    |  0.3322   |  291.2    |  37.3     |  622.5    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.08598	validation's rmse: 6.451
# [1000]	training's rmse: 1.84431	validation's rmse: 6.69999
# Early stopping, best iteration is:
# [6]	training's rmse: 6.90342	validation's rmse: 5.63895
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.12027	validation's rmse: 5.99534
# [1000]	training's rmse: 1.89421	validation's rmse: 6.16509
# Early stopping, best iteration is:
# [6]	training's rmse: 6.94212	validation's rmse: 5.36648
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.59629	validation's rmse: 8.89586
# [1000]	training's rmse: 1.50115	validation's rmse: 8.98205
# Early stopping, best iteration is:
# [26]	training's rmse: 5.67219	validation's rmse: 8.56462
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.00875	validation's rmse: 7.30985
# [1000]	training's rmse: 1.84951	validation's rmse: 7.41806
# Early stopping, best iteration is:
# [23]	training's rmse: 6.2624	validation's rmse: 6.76489
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.08279	validation's rmse: 7.34618
# [1000]	training's rmse: 1.88053	validation's rmse: 7.54578
# Early stopping, best iteration is:
# [19]	training's rmse: 6.32418	validation's rmse: 6.91861
# |  23       | -6.747    |  0.8394   |  88.85    |  0.9884   |  0.1434   |  6.871    |  1.001    |  0.2873   |  179.7    |  71.6     |  654.6    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.80245	validation's rmse: 6.57301
# [1000]	training's rmse: 1.63412	validation's rmse: 6.74697
# Early stopping, best iteration is:
# [8]	training's rmse: 6.78249	validation's rmse: 5.71037
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.8469	validation's rmse: 5.9637
# [1000]	training's rmse: 1.73052	validation's rmse: 6.1086
# Early stopping, best iteration is:
# [9]	training's rmse: 6.78242	validation's rmse: 5.32037
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.31657	validation's rmse: 8.8017
# [1000]	training's rmse: 1.21867	validation's rmse: 8.89046
# Early stopping, best iteration is:
# [30]	training's rmse: 5.57037	validation's rmse: 8.58224
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.75709	validation's rmse: 7.30494
# [1000]	training's rmse: 1.69628	validation's rmse: 7.39967
# Early stopping, best iteration is:
# [26]	training's rmse: 6.11552	validation's rmse: 6.76392
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.96763	validation's rmse: 7.25597
# [1000]	training's rmse: 1.87816	validation's rmse: 7.44429
# Early stopping, best iteration is:
# [12]	training's rmse: 6.40894	validation's rmse: 6.90113
# |  24       | -6.752    |  0.6477   |  82.68    |  0.8509   |  0.2736   |  7.356    |  0.8351   |  0.2057   |  129.3    |  47.96    |  621.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.37787	validation's rmse: 6.44339
# [1000]	training's rmse: 2.16135	validation's rmse: 6.6469
# Early stopping, best iteration is:
# [9]	training's rmse: 6.81221	validation's rmse: 5.6575
# ########################################
# Training Fold -  2
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.34617	validation's rmse: 5.9392
# [1000]	training's rmse: 2.15416	validation's rmse: 6.16685
# Early stopping, best iteration is:
# [10]	training's rmse: 6.87888	validation's rmse: 5.3314
# ########################################
# Training Fold -  3
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 2.74724	validation's rmse: 8.71157
# [1000]	training's rmse: 1.63537	validation's rmse: 8.78871
# Early stopping, best iteration is:
# [125]	training's rmse: 4.70516	validation's rmse: 8.56287
# ########################################
# Training Fold -  4
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.27646	validation's rmse: 7.17641
# [1000]	training's rmse: 2.14786	validation's rmse: 7.32506
# Early stopping, best iteration is:
# [14]	training's rmse: 6.451	validation's rmse: 6.71848
# ########################################
# Training Fold -  5
# ####################
# Training for Y1
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 3.37022	validation's rmse: 7.18559
# [1000]	training's rmse: 2.24458	validation's rmse: 7.36641
# Early stopping, best iteration is:
# [33]	training's rmse: 6.18051	validation's rmse: 6.86469
# |  25       | -6.723    |  0.7512   |  100.0    |  0.9274   |  0.228    |  5.313    |  0.01     |  0.2006   |  153.8    |  69.64    |  636.9    |
# =================================================================================================================================================

# %%
print(lgbm_bo1.max)
# Out:
# {'target': -6.715773763699902, 'params': {'bagging_fraction': 0.7446132365786178, 'bagging_freq': 94.57044996418587, 'feature_fraction': 0.9012097906532421, 'feature_fraction_bynode': 0.2724293678054648, 'lambda_l1': 6.697079462213692, 'lambda_l2': 0.05709330859845584, 'learning_rate': 0.17588487226531224, 'min_data_in_leaf': 154.15270440199714, 'min_sum_hessian_in_leaf': 58.37985742493366, 'num_leaves': 622.1019844986934}}

# %%
def lgbm_cv2(learning_rate, num_leaves, feature_fraction, feature_fraction_bynode, bagging_fraction, bagging_freq, min_data_in_leaf, min_sum_hessian_in_leaf, lambda_l1, lambda_l2):
    params = {  'seed': seed,
                'feature_fraction_seed': seed,
                'bagging_seed': seed,
                'drop_seed': seed,
                'data_random_seed': seed,
                'objective': 'rmse',
                'boosting': 'gbdt',
                'verbosity': -1,
                'n_jobs': -1}
    params['learning_rate'] = max(min(learning_rate, 1), 0)
    params["num_leaves"] = int(round(num_leaves))
    params['feature_fraction'] = max(min(feature_fraction, 1), 0)
    params['feature_fraction_bynode'] = max(min(feature_fraction_bynode, 1), 0)
    params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
    params['min_data_in_leaf'] = int(round(min_data_in_leaf))
    params['min_sum_hessian_in_leaf'] = min_sum_hessian_in_leaf
    params['lambda_l1'] = lambda_l1
    params['lambda_l2'] = lambda_l2
    
    # K-fold cross valiation
    kfold = KFold(n_splits=FOLDS)
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X, y)):
        print("#"*40)
        print("Training Fold - ", fold+1)
        X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
        X_val, y_val     = X.iloc[val_idx]  , y.iloc[val_idx]

        # create lgb datasets
        train_data2 = lgb.Dataset(X_train, y_train.iloc[:,1], categorical_feature = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])
        val_data2   = lgb.Dataset(X_val,   y_val.iloc[:,1],   categorical_feature = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])
        
        print("#"*20)
        print("Training for Y2")
        model2 = lgb.train(params = params,
                         train_set = train_data2,
                         valid_sets = [train_data2, val_data2],
                         num_boost_round = 100000,
                         valid_names=["training", "validation"],
                         early_stopping_rounds = 1000,
                         verbose_eval = 500)

        # Predict validation set
        val_pred2[val_idx] = model2.predict(X_val)
    
    return -np.sqrt(mse(train_["Y2"], val_pred2))

# %%
pbounds2 = {'learning_rate': (0.05, 0.3),
        'num_leaves': (300, 700),
        'feature_fraction': (0.1, 0.5),
        'feature_fraction_bynode': (0.5, 0.99),
        'bagging_fraction': (0.01, 1),
        'bagging_freq': (10, 70),
        'min_data_in_leaf': (400, 1000),
        'min_sum_hessian_in_leaf':(5, 50),
       'lambda_l1': (0.1, 10),
        'lambda_l2': (0.1, 10)}

# %%
lgbm_bo2 = BayesianOptimization(f = lgbm_cv2, pbounds = pbounds2, verbose = 2, random_state = seed)

lgbm_bo2.maximize(init_points = 5, n_iter = 20)
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | featur... | lambda_l1 | lambda_l2 | learni... | min_da... | min_su... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 100.757	validation's rmse: 120.914
# [1000]	training's rmse: 88.6385	validation's rmse: 122.26
# Early stopping, best iteration is:
# [123]	training's rmse: 113.973	validation's rmse: 119.762
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 101.119	validation's rmse: 120.573
# [1000]	training's rmse: 89.0368	validation's rmse: 122.039
# Early stopping, best iteration is:
# [113]	training's rmse: 114.538	validation's rmse: 119.006
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 100.486	validation's rmse: 123.372
# [1000]	training's rmse: 88.4263	validation's rmse: 125.178
# Early stopping, best iteration is:
# [94]	training's rmse: 114.936	validation's rmse: 121.803
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 100.285	validation's rmse: 124.255
# [1000]	training's rmse: 88.3978	validation's rmse: 125.698
# Early stopping, best iteration is:
# [138]	training's rmse: 112.535	validation's rmse: 123.121
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 101.02	validation's rmse: 122.236
# [1000]	training's rmse: 88.9928	validation's rmse: 123.802
# Early stopping, best iteration is:
# [69]	training's rmse: 116.679	validation's rmse: 120.657
# |  1        | -120.9    |  0.05824  |  27.35    |  0.3884   |  0.5106   |  2.139    |  0.6027   |  0.1256   |  798.3    |  18.87    |  533.4    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 98.5354	validation's rmse: 122.509
# [1000]	training's rmse: 84.9171	validation's rmse: 124.458
# Early stopping, best iteration is:
# [113]	training's rmse: 113.903	validation's rmse: 120.799
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 98.9608	validation's rmse: 121.653
# [1000]	training's rmse: 85.2436	validation's rmse: 123.674
# Early stopping, best iteration is:
# [88]	training's rmse: 115.684	validation's rmse: 119.811
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 98.1037	validation's rmse: 124.376
# [1000]	training's rmse: 84.7676	validation's rmse: 126.655
# Early stopping, best iteration is:
# [99]	training's rmse: 114.197	validation's rmse: 122.24
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 98.0569	validation's rmse: 125.522
# [1000]	training's rmse: 84.7386	validation's rmse: 127.295
# Early stopping, best iteration is:
# [86]	training's rmse: 114.646	validation's rmse: 123.873
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 98.5434	validation's rmse: 123.817
# [1000]	training's rmse: 85.003	validation's rmse: 125.983
# Early stopping, best iteration is:
# [71]	training's rmse: 115.867	validation's rmse: 121.459
# |  2        | -121.6    |  0.07888  |  62.04    |  0.1533   |  0.5873   |  5.01     |  8.651    |  0.2397   |  982.3    |  39.17    |  453.7    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 82.1687	validation's rmse: 123.967
# [1000]	training's rmse: 61.9502	validation's rmse: 126.363
# Early stopping, best iteration is:
# [85]	training's rmse: 110.657	validation's rmse: 120.573
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 82.427	validation's rmse: 123.238
# [1000]	training's rmse: 62.3268	validation's rmse: 126.073
# Early stopping, best iteration is:
# [87]	training's rmse: 110.33	validation's rmse: 119.607
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 81.8776	validation's rmse: 126.051
# [1000]	training's rmse: 61.7941	validation's rmse: 128.669
# Early stopping, best iteration is:
# [56]	training's rmse: 113.345	validation's rmse: 122.213
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 81.828	validation's rmse: 127.509
# [1000]	training's rmse: 62.1934	validation's rmse: 130.121
# Early stopping, best iteration is:
# [85]	training's rmse: 109.742	validation's rmse: 123.93
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 82.2531	validation's rmse: 125.038
# [1000]	training's rmse: 62.1959	validation's rmse: 127.657
# Early stopping, best iteration is:
# [74]	training's rmse: 111.522	validation's rmse: 121.031
# |  3        | -121.5    |  0.4146   |  52.8     |  0.2083   |  0.9185   |  9.14     |  7.631    |  0.1792   |  500.7    |  18.44    |  413.6    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 76.667	validation's rmse: 125.359
# [1000]	training's rmse: 54.8184	validation's rmse: 128.159
# Early stopping, best iteration is:
# [20]	training's rmse: 117.898	validation's rmse: 120.125
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 76.9704	validation's rmse: 124.929
# [1000]	training's rmse: 55.3391	validation's rmse: 127.761
# Early stopping, best iteration is:
# [34]	training's rmse: 115.554	validation's rmse: 119.544
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 76.461	validation's rmse: 127.849
# [1000]	training's rmse: 54.8215	validation's rmse: 130.98
# Early stopping, best iteration is:
# [41]	training's rmse: 113.789	validation's rmse: 122.384
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 76.5215	validation's rmse: 128.95
# [1000]	training's rmse: 55.3103	validation's rmse: 131.746
# Early stopping, best iteration is:
# [26]	training's rmse: 115.95	validation's rmse: 123.521
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 76.7216	validation's rmse: 127.361
# [1000]	training's rmse: 55.2505	validation's rmse: 130.539
# Early stopping, best iteration is:
# [33]	training's rmse: 115.335	validation's rmse: 121.296
# |  4        | -121.4    |  0.3339   |  37.61    |  0.3177   |  0.6065   |  8.019    |  7.294    |  0.2623   |  560.5    |  32.67    |  561.1    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 91.0726	validation's rmse: 123.431
# [1000]	training's rmse: 74.6264	validation's rmse: 125.77
# Early stopping, best iteration is:
# [38]	training's rmse: 116.816	validation's rmse: 119.93
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 91.562	validation's rmse: 122.356
# [1000]	training's rmse: 75.2018	validation's rmse: 125.216
# Early stopping, best iteration is:
# [47]	training's rmse: 116.196	validation's rmse: 119.13
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 90.9459	validation's rmse: 125.636
# [1000]	training's rmse: 74.4978	validation's rmse: 128.041
# Early stopping, best iteration is:
# [64]	training's rmse: 114.134	validation's rmse: 122.137
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 90.7944	validation's rmse: 126.859
# [1000]	training's rmse: 74.7159	validation's rmse: 129.436
# Early stopping, best iteration is:
# [42]	training's rmse: 115.601	validation's rmse: 123.652
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 91.5667	validation's rmse: 124.809
# [1000]	training's rmse: 75.217	validation's rmse: 127.161
# Early stopping, best iteration is:
# [45]	training's rmse: 115.921	validation's rmse: 121.108
# |  5        | -121.2    |  0.3929   |  34.62    |  0.4241   |  0.7942   |  8.994    |  4.951    |  0.2571   |  915.3    |  40.48    |  655.1    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 95.2741	validation's rmse: 121.853
# [1000]	training's rmse: 80.4385	validation's rmse: 123.885
# Early stopping, best iteration is:
# [82]	training's rmse: 114.122	validation's rmse: 119.692
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 95.3479	validation's rmse: 121.647
# [1000]	training's rmse: 80.6553	validation's rmse: 123.934
# Early stopping, best iteration is:
# [59]	training's rmse: 115.928	validation's rmse: 119.089
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 94.7153	validation's rmse: 124.555
# [1000]	training's rmse: 80.1487	validation's rmse: 126.892
# Early stopping, best iteration is:
# [66]	training's rmse: 114.764	validation's rmse: 121.918
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 94.8883	validation's rmse: 125.4
# [1000]	training's rmse: 80.2856	validation's rmse: 127.365
# Early stopping, best iteration is:
# [73]	training's rmse: 114.093	validation's rmse: 123.124
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 95.1253	validation's rmse: 123.378
# [1000]	training's rmse: 80.6144	validation's rmse: 125.619
# Early stopping, best iteration is:
# [66]	training's rmse: 114.983	validation's rmse: 120.842
# |  6        | -120.9    |  0.2677   |  26.76    |  0.4874   |  0.7887   |  6.649    |  5.476    |  0.1708   |  802.0    |  8.897    |  532.0    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.881	validation's rmse: 120.676
# [1000]	training's rmse: 106.576	validation's rmse: 120.461
# [1500]	training's rmse: 101.55	validation's rmse: 120.685
# Early stopping, best iteration is:
# [968]	training's rmse: 106.923	validation's rmse: 120.428
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 113.106	validation's rmse: 119.961
# [1000]	training's rmse: 106.736	validation's rmse: 119.775
# [1500]	training's rmse: 101.683	validation's rmse: 120.152
# Early stopping, best iteration is:
# [671]	training's rmse: 110.589	validation's rmse: 119.656
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.515	validation's rmse: 122.309
# [1000]	training's rmse: 106.134	validation's rmse: 122.262
# [1500]	training's rmse: 101.138	validation's rmse: 122.693
# Early stopping, best iteration is:
# [689]	training's rmse: 109.788	validation's rmse: 122.076
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.04	validation's rmse: 123.396
# [1000]	training's rmse: 105.83	validation's rmse: 123.438
# [1500]	training's rmse: 100.948	validation's rmse: 123.878
# Early stopping, best iteration is:
# [640]	training's rmse: 110.134	validation's rmse: 123.33
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.57	validation's rmse: 120.872
# [1000]	training's rmse: 106.504	validation's rmse: 121.235
# Early stopping, best iteration is:
# [475]	training's rmse: 112.926	validation's rmse: 120.844
# |  7        | -121.3    |  0.01     |  26.87    |  0.1      |  0.5      |  0.1      |  0.1      |  0.05     |  767.3    |  50.0     |  590.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.469	validation's rmse: 120.254
# [1000]	training's rmse: 106.232	validation's rmse: 120.204
# [1500]	training's rmse: 101.294	validation's rmse: 120.538
# Early stopping, best iteration is:
# [711]	training's rmse: 109.623	validation's rmse: 120.088
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.717	validation's rmse: 119.555
# [1000]	training's rmse: 106.549	validation's rmse: 119.76
# [1500]	training's rmse: 101.583	validation's rmse: 120.233
# Early stopping, best iteration is:
# [550]	training's rmse: 112.011	validation's rmse: 119.511
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.139	validation's rmse: 122.087
# [1000]	training's rmse: 105.808	validation's rmse: 122.263
# [1500]	training's rmse: 100.866	validation's rmse: 122.844
# Early stopping, best iteration is:
# [586]	training's rmse: 110.845	validation's rmse: 122.016
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 111.735	validation's rmse: 123.125
# [1000]	training's rmse: 105.648	validation's rmse: 123.343
# [1500]	training's rmse: 100.744	validation's rmse: 123.795
# Early stopping, best iteration is:
# [543]	training's rmse: 111.112	validation's rmse: 123.089
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 112.304	validation's rmse: 120.541
# [1000]	training's rmse: 106.208	validation's rmse: 121.132
# Early stopping, best iteration is:
# [465]	training's rmse: 112.807	validation's rmse: 120.511
# |  8        | -121.0    |  0.01     |  29.19    |  0.1325   |  0.5      |  0.1      |  0.1      |  0.05     |  795.2    |  46.04    |  493.5    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 91.7639	validation's rmse: 122.991
# [1000]	training's rmse: 75.3383	validation's rmse: 125.264
# Early stopping, best iteration is:
# [54]	training's rmse: 115.577	validation's rmse: 119.933
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 91.923	validation's rmse: 122.304
# [1000]	training's rmse: 75.4674	validation's rmse: 124.871
# Early stopping, best iteration is:
# [50]	training's rmse: 116.054	validation's rmse: 119.166
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 91.1827	validation's rmse: 125.004
# [1000]	training's rmse: 74.9165	validation's rmse: 127.665
# Early stopping, best iteration is:
# [62]	training's rmse: 114.274	validation's rmse: 121.876
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 91.3834	validation's rmse: 126.8
# [1000]	training's rmse: 75.3521	validation's rmse: 129.086
# Early stopping, best iteration is:
# [45]	training's rmse: 115.671	validation's rmse: 123.546
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 92.0038	validation's rmse: 124.425
# [1000]	training's rmse: 75.7809	validation's rmse: 126.89
# Early stopping, best iteration is:
# [55]	training's rmse: 115.223	validation's rmse: 121.152
# |  9        | -121.1    |  0.6271   |  68.7     |  0.3268   |  0.8562   |  5.324    |  5.771    |  0.2207   |  822.8    |  42.66    |  542.1    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 110.217	validation's rmse: 119.802
# [1000]	training's rmse: 103.212	validation's rmse: 120.325
# Early stopping, best iteration is:
# [365]	training's rmse: 112.568	validation's rmse: 119.697
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 110.345	validation's rmse: 119.077
# [1000]	training's rmse: 103.344	validation's rmse: 119.786
# Early stopping, best iteration is:
# [334]	training's rmse: 113.205	validation's rmse: 118.895
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.871	validation's rmse: 121.686
# [1000]	training's rmse: 102.925	validation's rmse: 122.402
# Early stopping, best iteration is:
# [312]	training's rmse: 113.114	validation's rmse: 121.476
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.549	validation's rmse: 123.005
# [1000]	training's rmse: 102.722	validation's rmse: 123.679
# Early stopping, best iteration is:
# [337]	training's rmse: 112.34	validation's rmse: 122.897
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 110.155	validation's rmse: 120.723
# [1000]	training's rmse: 103.23	validation's rmse: 121.329
# Early stopping, best iteration is:
# [239]	training's rmse: 114.814	validation's rmse: 120.425
# |  10       | -120.7    |  0.01     |  34.02    |  0.2861   |  0.5      |  0.1      |  0.1      |  0.05     |  752.3    |  8.835    |  520.0    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 105.449	validation's rmse: 120.113
# [1000]	training's rmse: 95.757	validation's rmse: 121.022
# Early stopping, best iteration is:
# [166]	training's rmse: 114.236	validation's rmse: 119.536
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 105.407	validation's rmse: 119.653
# [1000]	training's rmse: 95.6767	validation's rmse: 120.871
# Early stopping, best iteration is:
# [210]	training's rmse: 112.917	validation's rmse: 118.895
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 104.933	validation's rmse: 122.237
# [1000]	training's rmse: 95.269	validation's rmse: 123.409
# Early stopping, best iteration is:
# [140]	training's rmse: 114.745	validation's rmse: 121.537
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 104.774	validation's rmse: 123.694
# [1000]	training's rmse: 95.1654	validation's rmse: 124.761
# Early stopping, best iteration is:
# [137]	training's rmse: 114.495	validation's rmse: 123.08
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 105.358	validation's rmse: 121.343
# [1000]	training's rmse: 95.702	validation's rmse: 122.554
# Early stopping, best iteration is:
# [140]	training's rmse: 114.904	validation's rmse: 120.468
# |  11       | -120.7    |  0.3775   |  36.5     |  0.2679   |  0.782    |  2.583    |  3.234    |  0.07993  |  753.3    |  6.787    |  522.7    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 80.2963	validation's rmse: 125.403
# [1000]	training's rmse: 59.4581	validation's rmse: 128.051
# Early stopping, best iteration is:
# [26]	training's rmse: 116.9	validation's rmse: 120.298
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 80.5288	validation's rmse: 125.456
# [1000]	training's rmse: 60.0255	validation's rmse: 128.276
# Early stopping, best iteration is:
# [29]	training's rmse: 116.619	validation's rmse: 119.622
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 80.1009	validation's rmse: 128.557
# [1000]	training's rmse: 59.5412	validation's rmse: 131.688
# Early stopping, best iteration is:
# [21]	training's rmse: 117.421	validation's rmse: 122.604
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 79.9832	validation's rmse: 129.01
# [1000]	training's rmse: 59.8562	validation's rmse: 132.101
# Early stopping, best iteration is:
# [18]	training's rmse: 117.567	validation's rmse: 123.733
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 80.6755	validation's rmse: 126.747
# [1000]	training's rmse: 60.202	validation's rmse: 129.924
# Early stopping, best iteration is:
# [27]	training's rmse: 116.51	validation's rmse: 121.073
# |  12       | -121.5    |  1.0      |  10.0     |  0.5      |  0.5      |  0.1      |  0.1      |  0.3      |  701.5    |  5.0      |  484.7    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.574	validation's rmse: 119.67
# [1000]	training's rmse: 102.304	validation's rmse: 120.272
# Early stopping, best iteration is:
# [253]	training's rmse: 114.234	validation's rmse: 119.375
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.778	validation's rmse: 119.257
# [1000]	training's rmse: 102.565	validation's rmse: 119.991
# Early stopping, best iteration is:
# [239]	training's rmse: 114.754	validation's rmse: 118.89
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.182	validation's rmse: 121.861
# [1000]	training's rmse: 101.912	validation's rmse: 122.576
# Early stopping, best iteration is:
# [324]	training's rmse: 112.298	validation's rmse: 121.676
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 108.996	validation's rmse: 123.258
# [1000]	training's rmse: 101.816	validation's rmse: 123.83
# Early stopping, best iteration is:
# [248]	training's rmse: 113.655	validation's rmse: 122.959
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.514	validation's rmse: 120.84
# [1000]	training's rmse: 102.216	validation's rmse: 121.683
# Early stopping, best iteration is:
# [225]	training's rmse: 114.727	validation's rmse: 120.423
# |  13       | -120.7    |  0.01     |  69.67    |  0.5      |  0.5      |  0.1      |  0.1      |  0.05     |  752.0    |  29.56    |  512.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 82.9982	validation's rmse: 124.435
# [1000]	training's rmse: 63.2303	validation's rmse: 127.252
# Early stopping, best iteration is:
# [32]	training's rmse: 116.172	validation's rmse: 119.894
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 83.0504	validation's rmse: 124.651
# [1000]	training's rmse: 63.2239	validation's rmse: 127.631
# Early stopping, best iteration is:
# [29]	training's rmse: 116.911	validation's rmse: 119.506
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 82.6816	validation's rmse: 127.528
# [1000]	training's rmse: 63.206	validation's rmse: 130.644
# Early stopping, best iteration is:
# [33]	training's rmse: 115.712	validation's rmse: 122.287
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 82.8555	validation's rmse: 128.536
# [1000]	training's rmse: 63.3724	validation's rmse: 131.603
# Early stopping, best iteration is:
# [31]	training's rmse: 115.795	validation's rmse: 123.589
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 83.1042	validation's rmse: 126.232
# [1000]	training's rmse: 63.7358	validation's rmse: 129.138
# Early stopping, best iteration is:
# [19]	training's rmse: 118.156	validation's rmse: 121.303
# |  14       | -121.3    |  0.4753   |  67.04    |  0.362    |  0.9443   |  1.867    |  3.426    |  0.2942   |  766.6    |  10.32    |  477.1    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.368	validation's rmse: 119.601
# [1000]	training's rmse: 102.069	validation's rmse: 120.249
# Early stopping, best iteration is:
# [249]	training's rmse: 114.202	validation's rmse: 119.406
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.638	validation's rmse: 119.105
# [1000]	training's rmse: 102.328	validation's rmse: 119.917
# Early stopping, best iteration is:
# [265]	training's rmse: 114.06	validation's rmse: 118.754
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.082	validation's rmse: 121.908
# [1000]	training's rmse: 101.655	validation's rmse: 122.629
# Early stopping, best iteration is:
# [232]	training's rmse: 114.2	validation's rmse: 121.643
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 108.827	validation's rmse: 123.22
# [1000]	training's rmse: 101.595	validation's rmse: 123.88
# Early stopping, best iteration is:
# [221]	training's rmse: 114.161	validation's rmse: 122.962
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.381	validation's rmse: 120.881
# [1000]	training's rmse: 102.05	validation's rmse: 121.717
# Early stopping, best iteration is:
# [227]	training's rmse: 114.601	validation's rmse: 120.417
# |  15       | -120.6    |  0.01     |  44.74    |  0.5      |  0.5      |  0.1      |  0.1      |  0.05     |  743.6    |  44.44    |  529.8    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 100.615	validation's rmse: 121.1
# [1000]	training's rmse: 88.3201	validation's rmse: 122.512
# Early stopping, best iteration is:
# [174]	training's rmse: 111.769	validation's rmse: 120.295
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 101.073	validation's rmse: 120.412
# [1000]	training's rmse: 88.6583	validation's rmse: 121.983
# Early stopping, best iteration is:
# [127]	training's rmse: 114.216	validation's rmse: 119.358
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 100.297	validation's rmse: 123.175
# [1000]	training's rmse: 88.1126	validation's rmse: 124.787
# Early stopping, best iteration is:
# [195]	training's rmse: 110.457	validation's rmse: 121.977
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 100.231	validation's rmse: 124.628
# [1000]	training's rmse: 88.1175	validation's rmse: 126.045
# Early stopping, best iteration is:
# [117]	training's rmse: 113.868	validation's rmse: 123.493
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 100.723	validation's rmse: 122.431
# [1000]	training's rmse: 88.5256	validation's rmse: 124.06
# Early stopping, best iteration is:
# [117]	training's rmse: 114.327	validation's rmse: 120.948
# |  16       | -121.2    |  0.428    |  69.68    |  0.1669   |  0.6569   |  1.534    |  0.9055   |  0.1206   |  723.0    |  20.77    |  559.1    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 93.1006	validation's rmse: 122.363
# [1000]	training's rmse: 77.162	validation's rmse: 124.217
# Early stopping, best iteration is:
# [77]	training's rmse: 113.951	validation's rmse: 119.855
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 93.3358	validation's rmse: 121.826
# [1000]	training's rmse: 77.6145	validation's rmse: 123.95
# Early stopping, best iteration is:
# [62]	training's rmse: 115.387	validation's rmse: 119.115
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 92.6895	validation's rmse: 124.785
# [1000]	training's rmse: 77.0354	validation's rmse: 127.319
# Early stopping, best iteration is:
# [61]	training's rmse: 114.932	validation's rmse: 122.06
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 92.7562	validation's rmse: 126.086
# [1000]	training's rmse: 77.2968	validation's rmse: 127.978
# Early stopping, best iteration is:
# [65]	training's rmse: 114.3	validation's rmse: 123.592
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 93.3362	validation's rmse: 123.777
# [1000]	training's rmse: 77.7042	validation's rmse: 125.957
# Early stopping, best iteration is:
# [47]	training's rmse: 116.512	validation's rmse: 120.753
# |  17       | -121.1    |  0.9436   |  14.05    |  0.3835   |  0.5863   |  3.72     |  4.619    |  0.1863   |  755.1    |  32.76    |  535.2    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 85.9697	validation's rmse: 124.112
# [1000]	training's rmse: 67.2801	validation's rmse: 126.729
# Early stopping, best iteration is:
# [33]	training's rmse: 116.578	validation's rmse: 120.238
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 86.2031	validation's rmse: 123.535
# [1000]	training's rmse: 67.5656	validation's rmse: 126.152
# Early stopping, best iteration is:
# [35]	training's rmse: 116.839	validation's rmse: 119.408
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 85.7807	validation's rmse: 126.343
# [1000]	training's rmse: 67.1504	validation's rmse: 129.234
# Early stopping, best iteration is:
# [34]	training's rmse: 116.186	validation's rmse: 121.94
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 85.7157	validation's rmse: 127.799
# [1000]	training's rmse: 67.3597	validation's rmse: 130.602
# Early stopping, best iteration is:
# [35]	training's rmse: 115.867	validation's rmse: 123.714
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 86.0754	validation's rmse: 125.976
# [1000]	training's rmse: 67.5537	validation's rmse: 129.133
# Early stopping, best iteration is:
# [41]	training's rmse: 115.585	validation's rmse: 121.251
# |  18       | -121.3    |  0.2739   |  53.25    |  0.2832   |  0.8561   |  4.318    |  1.573    |  0.2505   |  735.5    |  49.77    |  504.9    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 99.4611	validation's rmse: 121.062
# [1000]	training's rmse: 86.4921	validation's rmse: 122.591
# Early stopping, best iteration is:
# [117]	training's rmse: 113.771	validation's rmse: 119.728
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 99.6199	validation's rmse: 120.824
# [1000]	training's rmse: 86.7141	validation's rmse: 122.56
# Early stopping, best iteration is:
# [122]	training's rmse: 113.546	validation's rmse: 119.225
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 99.0497	validation's rmse: 123.533
# [1000]	training's rmse: 86.0922	validation's rmse: 125.29
# Early stopping, best iteration is:
# [99]	training's rmse: 114.302	validation's rmse: 121.855
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 98.9797	validation's rmse: 124.584
# [1000]	training's rmse: 86.3076	validation's rmse: 126.059
# Early stopping, best iteration is:
# [117]	training's rmse: 113.005	validation's rmse: 123.119
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 99.1804	validation's rmse: 122.643
# [1000]	training's rmse: 86.3613	validation's rmse: 124.24
# Early stopping, best iteration is:
# [63]	training's rmse: 116.628	validation's rmse: 120.88
# |  19       | -121.0    |  0.8771   |  52.51    |  0.2613   |  0.5709   |  3.909    |  1.122    |  0.1361   |  756.7    |  24.0     |  538.5    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.471	validation's rmse: 119.552
# [1000]	training's rmse: 102.246	validation's rmse: 120.108
# Early stopping, best iteration is:
# [344]	training's rmse: 112.32	validation's rmse: 119.39
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.814	validation's rmse: 119.205
# [1000]	training's rmse: 102.528	validation's rmse: 119.935
# Early stopping, best iteration is:
# [254]	training's rmse: 114.431	validation's rmse: 118.903
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.196	validation's rmse: 121.819
# [1000]	training's rmse: 101.901	validation's rmse: 122.562
# Early stopping, best iteration is:
# [250]	training's rmse: 113.867	validation's rmse: 121.567
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.109	validation's rmse: 123.216
# [1000]	training's rmse: 101.95	validation's rmse: 123.821
# Early stopping, best iteration is:
# [227]	training's rmse: 114.263	validation's rmse: 122.994
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.505	validation's rmse: 120.84
# [1000]	training's rmse: 102.386	validation's rmse: 121.607
# Early stopping, best iteration is:
# [223]	training's rmse: 114.785	validation's rmse: 120.517
# |  20       | -120.7    |  0.01     |  46.51    |  0.5      |  0.5      |  0.1      |  0.1      |  0.05     |  755.4    |  27.3     |  515.6    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.321	validation's rmse: 119.618
# [1000]	training's rmse: 101.925	validation's rmse: 120.115
# Early stopping, best iteration is:
# [266]	training's rmse: 113.81	validation's rmse: 119.405
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.538	validation's rmse: 119.125
# [1000]	training's rmse: 102.037	validation's rmse: 119.861
# Early stopping, best iteration is:
# [222]	training's rmse: 114.932	validation's rmse: 118.709
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 108.943	validation's rmse: 121.85
# [1000]	training's rmse: 101.53	validation's rmse: 122.581
# Early stopping, best iteration is:
# [256]	training's rmse: 113.499	validation's rmse: 121.576
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 108.829	validation's rmse: 123.224
# [1000]	training's rmse: 101.54	validation's rmse: 123.851
# Early stopping, best iteration is:
# [203]	training's rmse: 114.605	validation's rmse: 122.957
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.335	validation's rmse: 120.782
# [1000]	training's rmse: 102.032	validation's rmse: 121.609
# Early stopping, best iteration is:
# [222]	training's rmse: 114.684	validation's rmse: 120.414
# |  21       | -120.6    |  0.01     |  54.41    |  0.5      |  0.5      |  0.1      |  0.1      |  0.05     |  739.0    |  14.32    |  517.6    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.274	validation's rmse: 119.664
# [1000]	training's rmse: 101.76	validation's rmse: 120.303
# Early stopping, best iteration is:
# [242]	training's rmse: 114.316	validation's rmse: 119.428
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.422	validation's rmse: 119.209
# [1000]	training's rmse: 101.848	validation's rmse: 120.015
# Early stopping, best iteration is:
# [207]	training's rmse: 115.264	validation's rmse: 118.885
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 108.833	validation's rmse: 121.811
# [1000]	training's rmse: 101.373	validation's rmse: 122.61
# Early stopping, best iteration is:
# [293]	training's rmse: 112.71	validation's rmse: 121.609
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 108.689	validation's rmse: 123.192
# [1000]	training's rmse: 101.305	validation's rmse: 123.89
# Early stopping, best iteration is:
# [266]	training's rmse: 113.05	validation's rmse: 122.94
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 109.182	validation's rmse: 120.883
# [1000]	training's rmse: 101.703	validation's rmse: 121.741
# Early stopping, best iteration is:
# [172]	training's rmse: 115.82	validation's rmse: 120.463
# |  22       | -120.7    |  0.01     |  37.28    |  0.5      |  0.5      |  0.1      |  0.1      |  0.05     |  731.8    |  23.92    |  527.7    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 97.4688	validation's rmse: 121.164
# [1000]	training's rmse: 83.7605	validation's rmse: 122.861
# Early stopping, best iteration is:
# [95]	training's rmse: 114.249	validation's rmse: 119.655
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 97.8088	validation's rmse: 120.973
# [1000]	training's rmse: 84.0682	validation's rmse: 122.695
# Early stopping, best iteration is:
# [95]	training's rmse: 114.271	validation's rmse: 118.976
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 97.2117	validation's rmse: 123.933
# [1000]	training's rmse: 83.5514	validation's rmse: 125.771
# Early stopping, best iteration is:
# [71]	training's rmse: 115.126	validation's rmse: 121.843
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 97.2052	validation's rmse: 125.151
# [1000]	training's rmse: 83.6364	validation's rmse: 126.766
# Early stopping, best iteration is:
# [110]	training's rmse: 112.582	validation's rmse: 123.167
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 97.6119	validation's rmse: 122.298
# [1000]	training's rmse: 84.0837	validation's rmse: 124.369
# Early stopping, best iteration is:
# [80]	training's rmse: 114.871	validation's rmse: 120.457
# |  23       | -120.8    |  0.3834   |  34.34    |  0.404    |  0.9554   |  3.966    |  4.278    |  0.1268   |  723.7    |  49.41    |  554.9    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 87.1931	validation's rmse: 124.906
# [1000]	training's rmse: 68.4286	validation's rmse: 127.454
# Early stopping, best iteration is:
# [54]	training's rmse: 115.232	validation's rmse: 121.201
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 87.2726	validation's rmse: 124.324
# [1000]	training's rmse: 68.7889	validation's rmse: 126.857
# Early stopping, best iteration is:
# [66]	training's rmse: 114.114	validation's rmse: 120.444
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 86.8068	validation's rmse: 127.444
# [1000]	training's rmse: 68.2431	validation's rmse: 130.278
# Early stopping, best iteration is:
# [43]	training's rmse: 116.168	validation's rmse: 123.266
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 86.849	validation's rmse: 128.126
# [1000]	training's rmse: 68.5635	validation's rmse: 130.776
# Early stopping, best iteration is:
# [40]	training's rmse: 115.733	validation's rmse: 124.398
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 87.2387	validation's rmse: 126.539
# [1000]	training's rmse: 68.6621	validation's rmse: 129.221
# Early stopping, best iteration is:
# [49]	training's rmse: 115.807	validation's rmse: 121.75
# |  24       | -122.2    |  0.261    |  69.03    |  0.1589   |  0.7943   |  7.428    |  8.574    |  0.2818   |  758.1    |  7.12     |  512.0    |
# ########################################
# Training Fold -  1
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 104.729	validation's rmse: 120.131
# [1000]	training's rmse: 94.5743	validation's rmse: 121.245
# Early stopping, best iteration is:
# [128]	training's rmse: 115.341	validation's rmse: 119.487
# ########################################
# Training Fold -  2
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 104.768	validation's rmse: 119.793
# [1000]	training's rmse: 94.6664	validation's rmse: 120.881
# Early stopping, best iteration is:
# [146]	training's rmse: 114.692	validation's rmse: 118.965
# ########################################
# Training Fold -  3
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 104.255	validation's rmse: 122.514
# [1000]	training's rmse: 94.2393	validation's rmse: 123.777
# Early stopping, best iteration is:
# [132]	training's rmse: 114.61	validation's rmse: 121.61
# ########################################
# Training Fold -  4
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 104.168	validation's rmse: 123.788
# [1000]	training's rmse: 94.412	validation's rmse: 124.9
# Early stopping, best iteration is:
# [133]	training's rmse: 114.389	validation's rmse: 122.969
# ########################################
# Training Fold -  5
# ####################
# Training for Y2
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 104.724	validation's rmse: 121.394
# [1000]	training's rmse: 94.7992	validation's rmse: 122.528
# Early stopping, best iteration is:
# [153]	training's rmse: 114.229	validation's rmse: 120.526
# |  25       | -120.7    |  0.1297   |  53.39    |  0.3484   |  0.6623   |  4.978    |  1.701    |  0.08003  |  729.9    |  31.08    |  524.7    |
# =================================================================================================================================================

# %%
print(lgbm_bo2.max)
# Out:
# {'target': -120.62179612097559, 'params': {'bagging_fraction': 0.01, 'bagging_freq': 54.41390829728485, 'feature_fraction': 0.5, 'feature_fraction_bynode': 0.5, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'learning_rate': 0.05, 'min_data_in_leaf': 739.0056075760633, 'min_sum_hessian_in_leaf': 14.315119859932201, 'num_leaves': 517.5526707826266}}

# %% [markdown]
# # CatBoost

# %%
# # Prediction arrays
# val_pred1 = np.zeros(X.shape[0])
# val_pred2 = np.zeros(X.shape[0])

# %%
# FOLDS = 5

# %%
# def cat_cv1(iterations, learning_rate, depth, l2_leaf_reg, colsample_bylevel):
#     params = {  "loss_function" : "RMSE",
#                 "eval_metric" : "RMSE", 
#                 "use_best_model" : True,
#                 "random_seed" : seed,}
#     params['iterations'] = int(round(iterations))
#     params['learning_rate'] = max(min(learning_rate, 1), 0)
#     params["depth"] = int(round(depth))
#     params['l2_leaf_reg'] = l2_leaf_reg
#     params['colsample_bylevel'] = max(min(colsample_bylevel, 1), 0)
    
#     # K-fold cross valiation
#     kfold = KFold(n_splits=FOLDS)
#     for fold, (train_idx, val_idx) in enumerate(kfold.split(X, y)):
#         print("#"*60)
#         print("Training Fold - ", fold+1)
#         X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
#         X_val, y_val     = X.iloc[val_idx]  , y.iloc[val_idx]

#         # create lgb datasets
#         train_data1 = Pool(X_train, y_train.iloc[:,0], cat_features = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])
#         val_data1   = Pool(X_val,   y_val.iloc[:,0],   cat_features = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])

#         # Train model
#         print("#"*20)
#         print("Training for Y1")
#         model1 = CatBoostRegressor(iterations = params['iterations'],
#                          depth = params['depth'],
#                          learning_rate = params['learning_rate'],
#                          loss_function = params['loss_function'],
#                          eval_metric = params['eval_metric'],
#                          use_best_model = params['use_best_model'],
#                          random_seed = params['random_seed'],
#                          l2_leaf_reg = params['l2_leaf_reg'],
#                          colsample_bylevel = params['colsample_bylevel'],
#                          early_stopping_rounds = 1000)
#         model1.fit(train_data1,
#                    eval_set=val_data1,
#                    verbose_eval=200)

#         # Predict validation set
#         val_pred1[val_idx] = model1.predict(X_val)
    
#     return -np.sqrt(mse(train_["Y1"], val_pred1))

# %%
# pbounds1 = {'iterations': (1000, 100000),
#         'learning_rate': (0.001, 1.0),
#         'depth': (1, 16),
#         'l2_leaf_reg': (0.5, 100),
#         'colsample_bylevel': (0.1, 0.99)}

# %%
# cat_bo1 = BayesianOptimization(f = cat_cv1, pbounds = pbounds1, verbose = 2, random_state = seed)

# %%
# cat_bo1.maximize(init_points = 3, n_iter = 10)

# %%
# print(cat_bo1.max)

# %%
# def cat_cv2(iterations, learning_rate, depth, l2_leaf_reg, colsample_bylevel):
#     params = {  "loss_function" : "RMSE",
#                 "eval_metric" : "RMSE", 
#                 "use_best_model" : True,
#                 "random_seed" : seed,}
#     params['iterations'] = int(round(iterations))
#     params['learning_rate'] = max(min(learning_rate, 1), 0)
#     params["depth"] = int(round(depth))
#     params['l2_leaf_reg'] = l2_leaf_reg
#     params['colsample_bylevel'] = max(min(colsample_bylevel, 1), 0)
    
#     # K-fold cross valiation
#     kfold = KFold(n_splits=FOLDS)
#     for fold, (train_idx, val_idx) in enumerate(kfold.split(X, y)):
#         print("#"*60)
#         print("Training Fold - ", fold+1)
#         X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
#         X_val, y_val     = X.iloc[val_idx]  , y.iloc[val_idx]

#         # create lgb datasets
#         train_data2 = Pool(X_train, y_train.iloc[:,1], cat_features = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])
#         val_data2   = Pool(X_val,   y_val.iloc[:,1],   cat_features = ["STATUS_CHECK", "CATEGORY_1", "CATEGORY_2"])

#         # Train model
#         print("#"*20)
#         print("Training for Y2")
#         model2 = CatBoostRegressor(iterations = params['iterations'],
#                          depth = params['depth'],
#                          learning_rate = params['learning_rate'],
#                          loss_function = params['loss_function'],
#                          eval_metric = params['eval_metric'],
#                          use_best_model = params['use_best_model'],
#                          random_seed = params['random_seed'],
#                          l2_leaf_reg = params['l2_leaf_reg'],
#                          colsample_bylevel = params['colsample_bylevel'],
#                          early_stopping_rounds = 1000)
#         model2.fit(train_data2,
#                    eval_set=val_data2,
#                    verbose_eval=200)

#         # Predict validation set
#         val_pred2[val_idx] = model2.predict(X_val)
    
#     return -np.sqrt(mse(train_["Y2"], val_pred2))

# %%
# pbounds2 = {'iterations': (1000, 100000),
#         'learning_rate': (0.001, 1.0),
#         'depth': (1, 16),
#         'l2_leaf_reg': (0.5, 100),
#         'colsample_bylevel': (0.1, 0.99)}

# %%
# cat_bo2 = BayesianOptimization(f = cat_cv2, pbounds = pbounds2, verbose = 2, random_state = seed)

# %%
# cat_bo2.maximize(init_points = 3, n_iter = 10)

# %%
# print(cat_bo2.max)
